# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression

# %%
housePrices = pd.read_csv("Real estate.csv")
housePrices
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
Y = housePrices['Y house price of unit area']
Y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 414 entries, 0 to 413
# Series name: Y house price of unit area
# Non-Null Count  Dtype
# --------------  -----
# 414 non-null    float64
# dtypes: float64(1)
# memory usage: 3.4 KB

# %%
predictors = list(housePrices.columns)
predictors
predictors.remove('No')
predictors.remove('Y house price of unit area')
X = housePrices[predictors]
X
# Out:
#      X1 transaction date  X2 house age  \
# 0               2012.917          32.0
# 1               2012.917          19.5
# 2               2013.583          13.3
# 3               2013.500          13.3
# 4               2012.833           5.0
# ..                   ...           ...
# 409             2013.000          13.7
# 410             2012.667           5.6
# 411             2013.250          18.8
# 412             2013.000           8.1
# 413             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,train_size = 0.4,random_state=123)


model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,Y_test)
# Out:
# 0.6360270588641528

# %%
from sklearn.metrics import mean_absolute_error

y_pred = model.predict(X_test)

mean_absolute_error(Y_test,y_pred)
# Out:
# 5.98237766674131
